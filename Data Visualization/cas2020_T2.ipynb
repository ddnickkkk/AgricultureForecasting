# %% [markdown]
# ### The purpose to Visualize 'CAS2020_T2':
# #### -> to show multiple bar charts which represented ('a specific Province' vs 'all each type of crops') according to the amount of crop
# #### -> to show multiple bar charts which represented ('a specific crop' vs 'all each province') according to the amount of crop

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('KH_NIS_DF_CAS2020_T2_1.0_all.csv')
df
# Out:
#                 RESPONSIBLE_AGENCY: Responsible agency  \
# 0    NIS_MAFF: National Institute of Statistics, Mi...
# 1    NIS_MAFF: National Institute of Statistics, Mi...
# 2    NIS_MAFF: National Institute of Statistics, Mi...
# 3    NIS_MAFF: National Institute of Statistics, Mi...
# 4    NIS_MAFF: National Institute of Statistics, Mi...
# ..                                                 ...
# 513  NIS_MAFF: National Institute of Statistics, Mi...
# 514  NIS_MAFF: National Institute of Statistics, Mi...
# 515  NIS_MAFF: National Institute of Statistics, Mi...
# 516  NIS_MAFF: National Institute of Statistics, Mi...
# 517  NIS_MAFF: National Institute of Statistics, Mi...
#
#                               DATA_SOURCE: Data source  \
# 0    AG_HO_CULTIVATING_CROPS: Agricultural holdings...
# 1    AG_HO_CULTIVATING_CROPS: Agricultural holdings...
# 2    AG_HO_CULTIVATING_CROPS: Agricultural holdings...
# 3    AG_HO_CULTIVATING_CROPS: Agricultural holdings...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518 entries, 0 to 517
# Data columns (total 11 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   RESPONSIBLE_AGENCY: Responsible agency        518 non-null    object
#  1   DATA_SOURCE: Data source                      518 non-null    object
#  2   INDICATOR_DESCRIPTION: Indicator description  518 non-null    object
#  3   INDICATOR: Indicator                          518 non-null    object
#  4   REF_AREA: Reference area                      518 non-null    object
#  5   CROP: Crop                                    518 non-null    object
#  6   FREQ: Frequency                               518 non-null    object
#  7   UNIT_MEASURE: Unit of measure                 518 non-null    int64
#  8   TIME_PERIOD: Time period                      518 non-null    float64
# ...

# %%
df.describe()
# Out:
#        UNIT_MEASURE: Unit of measure  TIME_PERIOD: Time period  \
# count                          518.0              5.180000e+02
# mean                          2020.0              4.192085e+04
# std                              0.0              1.362368e+05
# min                           2020.0              1.000000e+03
# 25%                           2020.0              2.000000e+03
# 50%                           2020.0              6.000000e+03
# 75%                           2020.0              3.050000e+04
# max                           2020.0              1.920000e+06
#
#        OBS_VALUE: Observation value  Unnamed: 10
# count                           0.0          0.0
# mean                            NaN          NaN
# std                             NaN          NaN
# min                             NaN          NaN
# 25%                             NaN          NaN
# 50%                             NaN          NaN
# 75%                             NaN          NaN
# ...

# %%
unique_value1 = df['RESPONSIBLE_AGENCY: Responsible agency'].unique()
unique_value1
# Out:
# array(['NIS_MAFF: National Institute of Statistics, Ministry of Planning, and Ministry of Agriculture, Forestry and Fisheries'],
#       dtype=object)

# %%
unique_value2 = df['CROP: Crop'].unique()
unique_value2
# Out:
# array(['A: Annual'], dtype=object)

# %%
unique_value3 = df['FREQ: Frequency'].unique()
unique_value3
# Out:
# array(['N_HO: Number of holdings'], dtype=object)

# %%
# to_delete1 = 'ASIKHM024: '
# p1 = df['INDICATOR: Indicator'].str.replace(to_delete1,"")
# p1

# to remove ASIKHM in province-names
pro_code = ["","007", "018", "094", "005", "011", "016", "091", "008", "014", "021","092", "002", "006","017","024",
           "093","009","023","010","013","019","003","012","020","025","001","004","015","022"]
for code in pro_code:
    to_delete = f'ASIKHM{code}: '
    df['INDICATOR: Indicator'] = df['INDICATOR: Indicator'].str.replace(to_delete, "")

# to remove code in crops
c_code = ["_T","101","102","103","105","203","302","402","403","441","522","811","801",
            "816","818","861","911","921","931","202","401","502","521","524","527",
            "530","532","562","817","820","828"]
for code in c_code:
    to_delete = f'{code}: '
    df['REF_AREA: Reference area'] = df['REF_AREA: Reference area'].str.replace(to_delete, "")

# to drop some columns
df = df.drop(['RESPONSIBLE_AGENCY: Responsible agency', 'DATA_SOURCE: Data source', 
            'INDICATOR_DESCRIPTION: Indicator description', 'CROP: Crop', 
            'FREQ: Frequency', 'UNIT_MEASURE: Unit of measure', 'OBS_VALUE: Observation value', 
            'Unnamed: 10'], axis=1)
df
# Out:
#     INDICATOR: Indicator REF_AREA: Reference area  TIME_PERIOD: Time period
# 0               Cambodia                    Total                 1920000.0
# 1               Cambodia       Non-aromatic paddy                 1247000.0
# 2               Cambodia           Aromatic paddy                  316000.0
# 3               Cambodia             Sticky paddy                   26000.0
# 4               Cambodia                    Maize                   51000.0
# ..                   ...                      ...                       ...
# 513               Pailin                    Total                    6000.0
# 514               Pailin                    Maize                    2000.0
# 515               Pailin                  Cassava                    4000.0
# 516               Pailin                    Mango                    3000.0
# 517               Pailin                  Coconut                    1000.0
#
# [518 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518 entries, 0 to 517
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   INDICATOR: Indicator      518 non-null    object
#  1   REF_AREA: Reference area  518 non-null    object
#  2   TIME_PERIOD: Time period  518 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 12.3+ KB

# %% [markdown]
# There is no missing value.

# %%
df.describe()
# Out:
#        TIME_PERIOD: Time period
# count              5.180000e+02
# mean               4.192085e+04
# std                1.362368e+05
# min                1.000000e+03
# 25%                2.000000e+03
# 50%                6.000000e+03
# 75%                3.050000e+04
# max                1.920000e+06

# %%
unique_value4 = df['INDICATOR: Indicator'].unique()
unique_value4
# Out:
# array(['Cambodia', 'Coastal Region', 'Kampot', 'Koh Kong',
#        'Preah Sihanouk', 'Kep', 'Plateau and Mountain Region',
#        'Kampong Speu', 'Kratie', 'Mondul Kiri', 'Preah Vihear',
#        'Ratanak Kiri', 'Stung Treng', 'Plains Region', 'Kampong Cham',
#        'Kandal', 'Phnom Penh', 'Prey Veng', 'Svay Rieng', 'Takeo',
#        'Tboung Khmum', 'Tonle Sap Region', 'Banteay Meanchey',
#        'Battambang', 'Kampong Chhnang', 'Kampong Thom', 'Pursat',
#        'Siem Reap', 'Otdar Meanchey', 'Pailin'], dtype=object)

# %%
unique_value5 = df['REF_AREA: Reference area'].unique()
unique_value5
# Out:
# array(['Total', 'Non-aromatic paddy', 'Aromatic paddy', 'Sticky paddy',
#        'Maize', 'Cassava', 'Mungbean', 'Soybean', 'Sesame', 'Sugarcane',
#        'Cucumber', 'Banana', 'Oranges', 'Mango', 'Pineapple', 'Cashew',
#        'Coconut', 'Black pepper', 'Rubber', 'Sweet potato',
#        'Ground nut (peanut)', 'Cabbage', 'Chili', 'Eggplant', 'Pumpkin',
#        'Tomato', 'Watermelon', 'Yard long bean', 'Papaya', 'Jackfruit',
#        'Durian'], dtype=object)

# %%
df[['TIME_PERIOD: Time period']].hist(grid=False, color='green', sharey=True);

# %%
df.boxplot(column=['TIME_PERIOD: Time period']);

# %%
unique_value5 = df['REF_AREA: Reference area'].unique()
unique_value5
# Out:
# array(['Total', 'Non-aromatic paddy', 'Aromatic paddy', 'Sticky paddy',
#        'Maize', 'Cassava', 'Mungbean', 'Soybean', 'Sesame', 'Sugarcane',
#        'Cucumber', 'Banana', 'Oranges', 'Mango', 'Pineapple', 'Cashew',
#        'Coconut', 'Black pepper', 'Rubber', 'Sweet potato',
#        'Ground nut (peanut)', 'Cabbage', 'Chili', 'Eggplant', 'Pumpkin',
#        'Tomato', 'Watermelon', 'Yard long bean', 'Papaya', 'Jackfruit',
#        'Durian'], dtype=object)

# %% [markdown]
# There are 31 types of crops, so I would like to check each type according to each province in Cambodia.

# %%
# Non-aromatic paddy
paddy = df[df["REF_AREA: Reference area"] == "Non-aromatic paddy"]

bar_name = paddy["INDICATOR: Indicator"]
plt.bar(bar_name, paddy["TIME_PERIOD: Time period"])
plt.xlabel("Province")
plt.ylabel("Amount of crop(Non-aromatic paddy)")
plt.title("Number of crop Non-aromatic paddy in different provinces")
plt.xticks(rotation=90)
plt.show()

# %%
# Aromatic paddy
paddy = df[df["REF_AREA: Reference area"] == "Aromatic paddy"]

bar_name = paddy["INDICATOR: Indicator"]
plt.bar(bar_name, paddy["TIME_PERIOD: Time period"])
plt.xlabel("Province")
plt.ylabel("Amount of crop(Aromatic paddy)")
plt.title("Number of crop Aromatic paddy in different provinces")
plt.xticks(rotation=90)
plt.show()

# %%
# Sticky paddy
paddy = df[df["REF_AREA: Reference area"] == "Sticky paddy"]

bar_name = paddy["INDICATOR: Indicator"]
plt.bar(bar_name, paddy["TIME_PERIOD: Time period"])
plt.xlabel("Province")
plt.ylabel("Amount of crop(Sticky paddy)")
plt.title("Number of crop Sticky paddy in different provinces")
plt.xticks(rotation=90)
plt.show()

# %%
# Maize
paddy = df[df["REF_AREA: Reference area"] == "Maize"]

bar_name = paddy["INDICATOR: Indicator"]
plt.bar(bar_name, paddy["TIME_PERIOD: Time period"])
plt.xlabel("Province")
plt.ylabel("Amount of crop(Maize)")
plt.title("Number of crop Maize in different provinces")
plt.xticks(rotation=90)
plt.show()

# %%
# Cassava
paddy = df[df["REF_AREA: Reference area"] == "Cassava"]

bar_name = paddy["INDICATOR: Indicator"]
plt.bar(bar_name, paddy["TIME_PERIOD: Time period"])
plt.xlabel("Province")
plt.ylabel("Amount of crop(Cassava)")
plt.title("Number of crop Cassava in different provinces")
plt.xticks(rotation=90)
plt.show()

# %%
# Mungbean
paddy = df[df["REF_AREA: Reference area"] == "Mungbean"]

bar_name = paddy["INDICATOR: Indicator"]
plt.bar(bar_name, paddy["TIME_PERIOD: Time period"])
plt.xlabel("Province")
plt.ylabel("Amount of crop(Mungbean)")
plt.title("Number of crop Mungbean in different provinces")
plt.xticks(rotation=90)
plt.show()

# %%
# Soybean
paddy = df[df["REF_AREA: Reference area"] == "Soybean"]

bar_name = paddy["INDICATOR: Indicator"]
plt.bar(bar_name, paddy["TIME_PERIOD: Time period"])
plt.xlabel("Province")
plt.ylabel("Amount of crop(Soybean)")
plt.title("Number of crop Soybean in different provinces")
plt.xticks(rotation=90)
plt.show()

# %%
# Sesame
paddy = df[df["REF_AREA: Reference area"] == "Sesame"]

bar_name = paddy["INDICATOR: Indicator"]
plt.bar(bar_name, paddy["TIME_PERIOD: Time period"])
plt.xlabel("Province")
plt.ylabel("Amount of crop(Sesame)")
plt.title("Number of crop Sesame in different provinces")
plt.xticks(rotation=90)
plt.show()

# %%
# Sugarcane
paddy = df[df["REF_AREA: Reference area"] == "Sugarcane"]

bar_name = paddy["INDICATOR: Indicator"]
plt.bar(bar_name, paddy["TIME_PERIOD: Time period"])
plt.xlabel("Province")
plt.ylabel("Amount of crop(Sugarcane)")
plt.title("Number of crop Sugarcane in different provinces")
plt.xticks(rotation=90)
plt.show()

# %%
# to be cont.

# %%
unique_value4 = df['INDICATOR: Indicator'].unique()
unique_value4
# Out:
# array(['Cambodia', 'Coastal Region', 'Kampot', 'Koh Kong',
#        'Preah Sihanouk', 'Kep', 'Plateau and Mountain Region',
#        'Kampong Speu', 'Kratie', 'Mondul Kiri', 'Preah Vihear',
#        'Ratanak Kiri', 'Stung Treng', 'Plains Region', 'Kampong Cham',
#        'Kandal', 'Phnom Penh', 'Prey Veng', 'Svay Rieng', 'Takeo',
#        'Tboung Khmum', 'Tonle Sap Region', 'Banteay Meanchey',
#        'Battambang', 'Kampong Chhnang', 'Kampong Thom', 'Pursat',
#        'Siem Reap', 'Otdar Meanchey', 'Pailin'], dtype=object)

# %% [markdown]
# I would like to know in each province, what crops that ppl mostly tend to grow each province.

# %%
# Coastal Region
paddy = df[df["INDICATOR: Indicator"] == "Coastal Region"]

bar_name = paddy["REF_AREA: Reference area"]
plt.bar(bar_name, paddy["TIME_PERIOD: Time period"])
plt.xlabel("Crop")
plt.ylabel("Amount")
plt.title("Amount crops in Coastal Region")
plt.xticks(rotation=90)
plt.show()

# %%
# Kampot
paddy = df[df["INDICATOR: Indicator"] == "Kampot"]

bar_name = paddy["REF_AREA: Reference area"]
plt.bar(bar_name, paddy["TIME_PERIOD: Time period"])
plt.xlabel("Crop")
plt.ylabel("Amount")
plt.title("Amount crops in Kampot")
plt.xticks(rotation=90)
plt.show()

# %%
# Koh Kong
paddy = df[df["INDICATOR: Indicator"] == "Koh Kong"]

bar_name = paddy["REF_AREA: Reference area"]
plt.bar(bar_name, paddy["TIME_PERIOD: Time period"])
plt.xlabel("Crop")
plt.ylabel("Amount")
plt.title("Amount crops in Koh Kong")
plt.xticks(rotation=90)
plt.show()

# %%
# Preah Sihanouk
paddy = df[df["INDICATOR: Indicator"] == "Preah Sihanouk"]

bar_name = paddy["REF_AREA: Reference area"]
plt.bar(bar_name, paddy["TIME_PERIOD: Time period"])
plt.xlabel("Crop")
plt.ylabel("Amount")
plt.title("Amount crops in Preah Sihanouk")
plt.xticks(rotation=90)
plt.show()

# %%
# Kep
paddy = df[df["INDICATOR: Indicator"] == "Kep"]

bar_name = paddy["REF_AREA: Reference area"]
plt.bar(bar_name, paddy["TIME_PERIOD: Time period"])
plt.xlabel("Crop")
plt.ylabel("Amount")
plt.title("Amount crops in Kep")
plt.xticks(rotation=90)
plt.show()

# %%
# Plateau and Mountain Region
paddy = df[df["INDICATOR: Indicator"] == "Plateau and Mountain Region"]

bar_name = paddy["REF_AREA: Reference area"]
plt.bar(bar_name, paddy["TIME_PERIOD: Time period"])
plt.xlabel("Crop")
plt.ylabel("Amount")
plt.title("Amount crops in Plateau and Mountain Region")
plt.xticks(rotation=90)
plt.show()

# %%
# to be cont.
